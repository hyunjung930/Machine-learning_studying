# %% [markdown]
# <a href="https://colab.research.google.com/github/hyunjung930/machine-learning/blob/hyunjung/0315%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %%
plt.plot(np.random.normal(0,1, 100)) #평균은 0 표준편차는 1 100개의 데이터 
#np.random.normal(0,1.3, 100) #더 넓은 값을 가지는 분산이다.

# %%
plt.plot(np.random.chisquare(10,100)) #정규분포, 파이제곱분포, 균등분포

# %%
plt.plot(np.random.chisquare(1,100))
